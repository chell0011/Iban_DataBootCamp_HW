# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities: 
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Am Timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=am timan
# Processing Record 2 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=eureka
# Processing Record 3 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=faanui
# Processing Record 4 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=butaritari
# Processing Record 5 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=luderitz
# Processing Record 6 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=atuona
# Processing Record 7 | Ust-Ordynskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ust-ordynskiy
# Processing Record 8 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hobart
# Processing Record 9 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nizhniy kuranakh
# Processing Record 10 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hermanus
# Processing Record 11 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=castro
# Processing Record 12 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=marystown
# Processing Record 13 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bluff
# Processing Record 14 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mataura
# Processing Record 15 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nikolskoye
# Processing Record 16 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=avera
# Processing Record 17 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cape town
# Processing Record 18 | Tomisato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tomisato
# Processing Record 19 | Kibondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kibondo
# City not found. Skipping...
# Processing Record 20 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port alfred
# Processing Record 21 | Aizkraukle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=aizkraukle
# Processing Record 22 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=airai
# Processing Record 23 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=fortuna
# Processing Record 24 | Koryazhma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=koryazhma
# Processing Record 25 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ngunguru
# Processing Record 26 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=smithers
# Processing Record 27 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kruisfontein
# Processing Record 28 | Kaupanger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kaupanger
# City not found. Skipping...
# Processing Record 29 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=klaksvik
# Processing Record 30 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lorengau
# Processing Record 31 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ponta do sol
# Processing Record 32 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=rikitea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto ayora
# Processing Record 34 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=talcahuano
# Processing Record 35 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tabas
# Processing Record 36 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ushuaia
# Processing Record 37 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=zyryanka
# Processing Record 38 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=constitucion
# Processing Record 39 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=leningradskiy
# Processing Record 40 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hambantota
# Processing Record 41 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saint george
# Processing Record 42 | Dungarpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dungarpur
# Processing Record 43 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sitka
# Processing Record 44 | Gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=gambela
# Processing Record 45 | Khuzdar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=khuzdar
# Processing Record 46 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yellowknife
# Processing Record 47 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hithadhoo
# Processing Record 48 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vaini
# Processing Record 49 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mar del plata
# Processing Record 50 | Zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=zunyi
# Processing Record 51 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kimbe
# Processing Record 52 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=albany
# Processing Record 53 | Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto carreno
# City not found. Skipping...
# Processing Record 54 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bredasdorp
# Processing Record 55 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=punta arenas
# Processing Record 56 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saldanha
# Processing Record 57 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bilma
# Processing Record 58 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tautira
# Processing Record 59 | Serenje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=serenje
# Processing Record 60 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=severo-kurilsk
# Processing Record 61 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=qaanaaq
# Processing Record 62 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ponta delgada
# Processing Record 63 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=jamestown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 64 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port augusta
# Processing Record 65 | Loralai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=loralai
# City not found. Skipping...
# Processing Record 66 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hamilton
# Processing Record 67 | Conceicao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=conceicao da barra
# Processing Record 68 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dikson
# Processing Record 69 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=upernavik
# Processing Record 70 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=busselton
# Processing Record 71 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=taltal
# Processing Record 72 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hasaki
# Processing Record 73 | Tsogni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tsogni
# Processing Record 74 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hilo
# Processing Record 75 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=arraial do cabo
# City not found. Skipping...
# Processing Record 76 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=avarua
# Processing Record 77 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nantucket
# Processing Record 78 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=georgetown
# Processing Record 79 | Coari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=coari
# Processing Record 80 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=te anau
# Processing Record 81 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=atambua
# Processing Record 82 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mehamn
# Processing Record 83 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bethel
# Processing Record 84 | Pozo Colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pozo colorado
# Processing Record 85 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kangaatsiaq
# Processing Record 86 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cockburn town
# Processing Record 87 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=adrar
# Processing Record 88 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=norman wells
# Processing Record 89 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vila velha
# Processing Record 90 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kargasok
# Processing Record 91 | Progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=progreso
# Processing Record 92 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=north bend
# Processing Record 93 | Dongzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dongzhen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 94 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=husavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 95 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=grand gaube
# Processing Record 96 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kapaa
# Processing Record 97 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tasiilaq
# Processing Record 98 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cabo san lucas
# City not found. Skipping...
# Processing Record 99 | Sao Paulo de Olivenca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sao paulo de olivenca
# Processing Record 100 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lebu
# Processing Record 101 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=carnarvon
# Processing Record 102 | Kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kamaishi
# Processing Record 103 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=katsuura
# Processing Record 104 | Langenau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=langenau
# City not found. Skipping...
# Processing Record 105 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=victoria
# City not found. Skipping...
# Processing Record 106 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 107 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=namatanai
# Processing Record 108 | Boa Esperanca do Sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=boa esperanca do sul
# Processing Record 109 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=chicama
# Processing Record 110 | Sao Felix do Xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sao felix do xingu
# Processing Record 111 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dali
# Processing Record 112 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ampanihy
# Processing Record 113 | Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=aripuana
# Processing Record 114 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yulara
# Processing Record 115 | Urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=urucara
# Processing Record 116 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=biak
# Processing Record 117 | Bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bintulu
# Processing Record 118 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tuatapere
# Processing Record 119 | Tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tromso
# Processing Record 120 | Aksum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=aksum
# Processing Record 121 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pacific grove
# Processing Record 122 | Nzega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nzega
# Processing Record 123 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=harper
# City not found. Skipping...
# Processing Record 124 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kavaratti
# Processing Record 125 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=palmer
# Processing Record 126 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=westport
# Processing Record 127 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ayan
# Processing Record 128 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=doha
# Processing Record 129 | Saint Augustine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saint augustine
# Processing Record 130 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=axim
# Processing Record 131 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=aasiaat
# Processing Record 132 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ribeira grande
# Processing Record 133 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=teya
# Processing Record 134 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=inuvik
# City not found. Skipping...
# Processing Record 135 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yar-sale
# Processing Record 136 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=moron
# Processing Record 137 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cherskiy
# Processing Record 138 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=salalah
# Processing Record 139 | Pskov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pskov
# Processing Record 140 | Tisul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tisul
# City not found. Skipping...
# Processing Record 141 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bambous virieux
# Processing Record 142 | Rakaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=rakaia
# Processing Record 143 | Skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=skjervoy
# Processing Record 144 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tura
# Processing Record 145 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tuktoyaktuk
# Processing Record 146 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saint-philippe
# Processing Record 147 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sao jose da coroa grande
# Processing Record 148 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=oranjemund
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 149 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ulladulla
# Processing Record 150 | Kapchorwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kapchorwa
# Processing Record 151 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=awbari
# Processing Record 152 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nabire
# Processing Record 153 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ancud
# City not found. Skipping...
# Processing Record 154 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=east london
# Processing Record 155 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yanam
# Processing Record 156 | Concordia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=concordia
# Processing Record 157 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=itarema
# Processing Record 158 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pevek
# Processing Record 159 | Jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=jasper
# Processing Record 160 | Saveh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saveh
# Processing Record 161 | Lere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lere
# Processing Record 162 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=margate
# Processing Record 163 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=barrow
# Processing Record 164 | Gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=gravdal
# Processing Record 165 | Uyemskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=uyemskiy
# Processing Record 166 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=northam
# Processing Record 167 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sao filipe
# Processing Record 168 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=inhambane
# Processing Record 169 | Milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=milkovo
# Processing Record 170 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=souillac
# City not found. Skipping...
# Processing Record 171 | Naustdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=naustdal
# Processing Record 172 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=belmonte
# Processing Record 173 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=henties bay
# Processing Record 174 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saint-pierre
# Processing Record 175 | Rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=rafaela
# Processing Record 176 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kahului
# Processing Record 177 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dunedin
# Processing Record 178 | Florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=florianopolis
# Processing Record 179 | Dayong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dayong
# Processing Record 180 | Adil-Yangiyurt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=adil-yangiyurt
# Processing Record 181 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=matara
# Processing Record 182 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ukiah
# Processing Record 183 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=caravelas
# Processing Record 184 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tiksi
# Processing Record 185 | Alvarado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=alvarado
# Processing Record 186 | Samarinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=samarinda
# Processing Record 187 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=khatanga
# Processing Record 188 | Felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=felanitx
# Processing Record 189 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=thompson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 190 | Nichinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nichinan
# Processing Record 191 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kaitangata
# Processing Record 192 | Moramanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=moramanga
# Processing Record 193 | Kosh-Agach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kosh-agach
# Processing Record 194 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=longyearbyen
# Processing Record 195 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=marienburg
# Processing Record 196 | Lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lamar
# Processing Record 197 | Terme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=terme
# Processing Record 198 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=makakilo city
# Processing Record 199 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port lincoln
# Processing Record 200 | Wana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=wana
# City not found. Skipping...
# Processing Record 201 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=codrington
# Processing Record 202 | Sukhobezvodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sukhobezvodnoye
# Processing Record 203 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=necochea
# Processing Record 204 | Pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pundaguitan
# Processing Record 205 | Mushie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mushie
# Processing Record 206 | Beaufort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=beaufort
# Processing Record 207 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=virginia beach
# Processing Record 208 | Lisakovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lisakovsk
# Processing Record 209 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hofn
# Processing Record 210 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=dukat
# Processing Record 211 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mahebourg
# Processing Record 212 | Kaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kaina
# Processing Record 213 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mayo
# Processing Record 214 | Praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=praya
# City not found. Skipping...
# Processing Record 215 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kieta
# Processing Record 216 | Manyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=manyana
# Processing Record 217 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=narsaq
# Processing Record 218 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=half moon bay
# Processing Record 219 | Meridian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=meridian
# Processing Record 220 | Sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sergeyevka
# Processing Record 221 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sampit
# Processing Record 222 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=la ronge
# Processing Record 223 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=acapulco
# Processing Record 224 | Salvador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=salvador
# Processing Record 225 | Soure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=soure
# Processing Record 226 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=banda aceh
# Processing Record 227 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hami
# Processing Record 228 | Terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=terrace
# Processing Record 229 | Yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yelizovo
# Processing Record 230 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=saint anthony
# Processing Record 231 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tilichiki
# Processing Record 232 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=chokurdakh
# Processing Record 233 | Swellendam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=swellendam
# Processing Record 234 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=shimoda
# Processing Record 235 | Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=canutama
# Processing Record 236 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=manggar
# Processing Record 237 | Coria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=coria
# Processing Record 238 | Vichy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vichy
# Processing Record 239 | Vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vila
# Processing Record 240 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=iqaluit
# Processing Record 241 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mount gambier
# City not found. Skipping...
# Processing Record 242 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=polunochnoye
# Processing Record 243 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vardo
# Processing Record 244 | Hasanabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hasanabad
# Processing Record 245 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mandalgovi
# Processing Record 246 | Ambulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ambulu
# Processing Record 247 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port macquarie
# Processing Record 248 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=salinas
# Processing Record 249 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sur
# Processing Record 250 | Sal Rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sal rei
# Processing Record 251 | Bodden Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bodden town
# City not found. Skipping...
# Processing Record 252 | Kempsey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kempsey
# Processing Record 253 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=havre-saint-pierre
# Processing Record 254 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sisimiut
# Processing Record 255 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vao
# Processing Record 256 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=wanning
# Processing Record 257 | Tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tigil
# Processing Record 258 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mizdah
# Processing Record 259 | Khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=khani
# Processing Record 260 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=provideniya
# Processing Record 261 | Uribia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=uribia
# Processing Record 262 | Bastrop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bastrop
# Processing Record 263 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port elizabeth
# Processing Record 264 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=khandyga
# Processing Record 265 | Muriwai Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=muriwai beach
# Processing Record 266 | Hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hohhot
# Processing Record 267 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=seoul
# Processing Record 268 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=launceston
# City not found. Skipping...
# Processing Record 269 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=manta
# Processing Record 270 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=touros
# City not found. Skipping...
# Processing Record 271 | Crisan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=crisan
# City not found. Skipping...
# Processing Record 272 | Goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=goma
# Processing Record 273 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=zhigansk
# Processing Record 274 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=new norfolk
# Processing Record 275 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cururupu
# Processing Record 276 | Serik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=serik
# City not found. Skipping...
# Processing Record 277 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cidreira
# City not found. Skipping...
# Processing Record 278 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=broome
# Processing Record 279 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cayenne
# Processing Record 280 | Ialibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ialibu
# Processing Record 281 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=davila
# Processing Record 282 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ahuimanu
# City not found. Skipping...
# Processing Record 283 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pisco
# Processing Record 284 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=usinsk
# Processing Record 285 | Abrau-Dyurso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=abrau-dyurso
# Processing Record 286 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=boende
# Processing Record 287 | Diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=diamantino
# Processing Record 288 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=thinadhoo
# Processing Record 289 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=oistins
# Processing Record 290 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=zhezkazgan
# Processing Record 291 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=komsomolskiy
# City not found. Skipping...
# Processing Record 292 | Arak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=arak
# Processing Record 293 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=qaqortoq
# Processing Record 294 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tiznit
# Processing Record 295 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=walvis bay
# Processing Record 296 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=clarence town
# Processing Record 297 | Oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=oktyabrskoye
# City not found. Skipping...
# Processing Record 298 | Peterhead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=peterhead
# Processing Record 299 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=olinda
# Processing Record 300 | Celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=celestun
# Processing Record 301 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kodiak
# Processing Record 302 | Areka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=areka
# Processing Record 303 | Puerto Baquerizo Moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto baquerizo moreno
# Processing Record 304 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=paamiut
# Processing Record 305 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=rocha
# City not found. Skipping...
# Processing Record 306 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hay river
# Processing Record 307 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ugoofaaru
# Processing Record 308 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=laguna
# Processing Record 309 | Mahbubabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mahbubabad
# Processing Record 310 | Hanmer Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=hanmer springs
# Processing Record 311 | Cape Canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cape canaveral
# Processing Record 312 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=san patricio
# Processing Record 313 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=naze
# Processing Record 314 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=guerrero negro
# Processing Record 315 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=fairbanks
# Processing Record 316 | Palkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=palkino
# Processing Record 317 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nacala
# Processing Record 318 | Ayia Galini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ayia galini
# Processing Record 319 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kodinsk
# Processing Record 320 | Santa Cruz de la Palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=santa cruz de la palma
# Processing Record 321 | Turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=turayf
# Processing Record 322 | Trairi
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=knokke-heist
# Processing Record 431 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=chernyshevskiy
# Processing Record 432 | Kibala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kibala
# Processing Record 433 | Mokrous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mokrous
# City not found. Skipping...
# Processing Record 434 | Moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=moree
# Processing Record 435 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=udachnyy
# City not found. Skipping...
# Processing Record 436 | Arenal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=arenal
# Processing Record 437 | Aquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=aquin
# Processing Record 438 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=portland
# Processing Record 439 | Kokuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kokuy
# Processing Record 440 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto colombia
# Processing Record 441 | Oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=oranjestad
# Processing Record 442 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bathsheba
# Processing Record 443 | Little Current
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=little current
# Processing Record 444 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto ayacucho
# City not found. Skipping...
# Processing Record 445 | Galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=galveston
# Processing Record 446 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bubaque
# Processing Record 447 | Kabalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kabalo
# Processing Record 448 | Senanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=senanga
# Processing Record 449 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mitsamiouli
# Processing Record 450 | Kaniama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kaniama
# Processing Record 451 | Ios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ios
# Processing Record 452 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=turukhansk
# Processing Record 453 | Revda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=revda
# Processing Record 454 | Talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=talaya
# Processing Record 455 | Kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kapuskasing
# Processing Record 456 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nanortalik
# Processing Record 457 | Montlucon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=montlucon
# Processing Record 458 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=eyl
# Processing Record 459 | Puerto Penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto penasco
# Processing Record 460 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=pangnirtung
# Processing Record 461 | Mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mbekenyera
# Processing Record 462 | Tadine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tadine
# Processing Record 463 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mahibadhoo
# Processing Record 464 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=san cristobal
# Processing Record 465 | Daugavpils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=daugavpils
# Processing Record 466 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=altay
# Processing Record 467 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=luganville
# City not found. Skipping...
# Processing Record 468 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=auki
# Processing Record 469 | Barentu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=barentu
# Processing Record 470 | Poli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=poli
# Processing Record 471 | Tres Picos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=tres picos
# Processing Record 472 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bandarbeyla
# Processing Record 473 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bud
# Processing Record 474 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kiama
# Processing Record 475 | Kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=kidal
# Processing Record 476 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=port blair
# Processing Record 477 | Les Escoumins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=les escoumins
# Processing Record 478 | Jurm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=jurm
# Processing Record 479 | Soller
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=soller
# Processing Record 480 | Ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ravar
# Processing Record 481 | Galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=galle
# Processing Record 482 | Borovoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=borovoy
# Processing Record 483 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mabaruma
# Processing Record 484 | Chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=chipinge
# Processing Record 485 | Waverly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=waverly
# Processing Record 486 | Turek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=turek
# Processing Record 487 | Sipe Sipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sipe sipe
# Processing Record 488 | Betanzos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=betanzos
# Processing Record 489 | Winder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=winder
# Processing Record 490 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=belaya gora
# Processing Record 491 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=faya
# Processing Record 492 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=coihaique
# Processing Record 493 | Beboto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=beboto
# Processing Record 494 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=buraydah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 495 | Puerto Madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=puerto madryn
# Processing Record 496 | Mumbwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mumbwa
# Processing Record 497 | Rosetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=rosetta
# Processing Record 498 | Nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nsanje
# City not found. Skipping...
# Processing Record 499 | Azanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=azanka
# Processing Record 500 | La Asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=la asuncion
# Processing Record 501 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=coquimbo
# Processing Record 502 | Ayna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ayna
# Processing Record 503 | Jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=jalingo
# Processing Record 504 | Lebanon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lebanon
# Processing Record 505 | Inverness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=inverness
# Processing Record 506 | La Palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=la palma
# Processing Record 507 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=muzhi
# Processing Record 508 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=buchanan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 509 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=batticaloa
# Processing Record 510 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=shakawe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 511 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=ishigaki
# Processing Record 512 | Phulabani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=phulabani
# Processing Record 513 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vanavara
# Processing Record 514 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=porbandar
# Processing Record 515 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=geraldton
# Processing Record 516 | Abashiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=abashiri
# Processing Record 517 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sao joao da barra
# Processing Record 518 | Atig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=atig
# Processing Record 519 | Cortez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=cortez
# Processing Record 520 | Bakchar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bakchar
# Processing Record 521 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=alice springs
# Processing Record 522 | Vokhtoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vokhtoga
# Processing Record 523 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=mount isa
# Processing Record 524 | Verkh-Usugli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=verkh-usugli
# Processing Record 525 | Castrillon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=castrillon
# Processing Record 526 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lompoc
# Processing Record 527 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=yerbogachen
# Processing Record 528 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=college
# Processing Record 529 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=sola
# Processing Record 530 | Vila do Maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vila do maio
# Processing Record 531 | Bhikangaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bhikangaon
# Processing Record 532 | Novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=novoagansk
# Processing Record 533 | Lubyany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=lubyany
# Processing Record 534 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=vila franca do campo
# Processing Record 535 | Bikaner
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=bikaner
# Processing Record 536 | Oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=oga
# Processing Record 537 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ce87a1e44d5c82ea424167e377cda2e&q=nelson bay

# %%
# Create a dictonary 
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}

# Create a data frame
weather_data = pd.DataFrame(weather_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %%
# Save df to CSV
weather_data.to_csv('weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Am Timan         100      TD  1563837149        91  11.04   20.28
# 1      Eureka           1      US  1563836881        72  40.80 -124.16
# 2      Faanui          30      PF  1563837151        80 -16.48 -151.75
# 3  Butaritari         100      KI  1563837152        70   3.07  172.79
# 4    Luderitz           0      NA  1563837153        93 -26.65   15.16
#
#    Max Temp  Wind Speed
# 0     73.61        2.98
# 1     66.20        9.17
# 2     79.01       18.66
# 3     85.13        7.78
# 4     48.20        5.82

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Written description of three observable trends based on the data.
# 1 - The cities located between 20-40 degrees latitiude have higher max temperatures.
# 2 - There is no correlation between latitude and cloudiness.
# 3 - There is no correlation between latitude and wind speed.
